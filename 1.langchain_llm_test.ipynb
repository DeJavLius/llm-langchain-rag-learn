# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv()
# Out:
# True

# %%
import os
from langchain_ollama import OllamaLLM
model = os.getenv("MODEL")
base_url = os.getenv("BASE_URL")

llm = OllamaLLM(model=model, base_url=base_url)
message = llm.invoke("너를 소개해")
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File /Users/DEV/Personal/Project/lecture/llm-langchain-rag/.venv/lib/python3.10/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File /Users/DEV/Personal/Project/lecture/llm-langchain-rag/.venv/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File /Users/DEV/Personal/Project/lecture/llm-langchain-rag/.venv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
# ...
